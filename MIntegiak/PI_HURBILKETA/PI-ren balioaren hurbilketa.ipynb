# %% [markdown]
# #### Azalpena:
#
# Mintegi honetan zorizko zenbakiak sortuz, Pi zenbakia hurbildu daitekeela ikusiko dugu.
#
# Beheko irudian dagoen zirkunferentziaren erradioa bat bada, gune berdearen azalera pi/4=0.78539816339 da
#
# <img src="Area-Of-Quadrant.png" width="500" height="600"/>
#
# Mintegi honetan N zorizko zenbaki sortuko dugu $(0,1)\times(0,1)$ karratuan eta, gune berdearen barruan daudenen proportzioa hartuko dugu pi/4-ren estimatzailetzat.
#
# #### Prozedura
#
#
# Talde bakoitzak algoritmo bat egingo dugu, ondokoa egingo duelarik. Hasieran, kontadore=0 balioa ezarri eta
# N aldiz, ondokoa egingo luke algoritmoak:
# * U(0,1) banaketa jarraitzen duen zenbaki bat sortu eta x deitu
# * U(0,1) banaketa jarraitzen duen zenbaki bat sortu eta y deitu
# * (x,y) bektorea gune berdean badago, kontadore=kontadore+1.
#
# pi/4-ren estimatzailetzat kontadore/N hartuko dugu.
#
#
# Demagun N=10 hartzen dugula eta ondoko x eta y balioak lortu ditugula (lehenengo x eta gero y)
#
# 0.305458415998146
# 0.130019224947318
# 0.424853572389111
# 0.389287578873336
# 0.345331720774993
# 0.857450289884582
# 0.829664820572361
# 0.832654735306278
# 0.542423763312399
# 0.306574273156002
#
#
# 0.603873022831976
# 0.0244657495059073
# 0.83397842105478
# 0.757854476338252
# 0.0798789577092975
# 0.845162711106241
# 0.175894538173452
# 0.217300115153193
# 0.444271652726457
# 0.947162109659985
#
# Ondoko grafikoan irudikatuko ditugu lortutako puntuak:
#
# <img src="untitled.jpg" width="500" height="600"/>
#
# Grafikoan ikusten da sortako 10 (x,y) puntuetatik 9 daudela gune berdean (hau da, c=9). Beraz, pi/4-ren estimatzaile bezala 9/10=0.9 hartuko dugu.
#
# Berriz exekutatuz gero gure algoritmoa N=10 izanik, ondoko irudia lortzen dugu
#
# <img src="untitled1.jpg" width="500" height="600"/>
#
# Eta c=8 balioa lortzen dugu. Hau da, estimatzaile ezberdina lortuko dugu, baina biak nahiko urrun daude pi/4 zenbakitik.
#
# Ikusiko dugu zer gertatzen den N handiago batekin. Demagun N=1000 dela. Kasu honetan, lortutako irudia ondokoa da.
#
# <img src="untitled2.jpg" width="500" height="600"/>
#
# Gure algoritmoarekin lortzen dugun balioa 0.762 da, izan ere sortutako 1000 puntuetatik 762-k betetzen dute gune berdean egotearen baldintza. Beraz, N handiagoarekin estimatzaile hobeagoa lortzen dugula ikusi dugu.
#
# Berriz exekutatzen badugu algoritmoa N=1000 balioarekin, ondokoa lortuko dugu:
#
# <img src="untitled3.jpg" width="500" height="600"/>
#
# Ikusten da lortutako 1000 puntuak ezberdinak direla aurreko adibidekoarekiko eta, gainera, pi/4 estimatzaile bezala 0.774 da. Alegia, sortutako 1000 puntuetatik 774-k betetzen dute gune berdean egotearen baldintza. Lortutako balio hau ere pi/4-ren estimatzaile ona dela ikusten da.
#
#
# Orain, lortutako estimatzailea pi/4-ra hurbiltzen dela ikusiko dugu goiko grafikako puntu kopurua (iterazioak) handitzen den heinean. Beheko irudian ikusten da lortutako emaitza.
#
# <img src="untitled4_0.png" width="500" height="600"/>
#
# Ohartuko gara, berriz ere pi/4-en hurbilketa iterazio kopuruaren arabera eginez lortutako emaitza aztertuz gero, ez dugula lehenengo iterazioetan (puntu kopurua txikia denean) balio berdina izango; hala ere, iterazio kopurua handia denean, bi estimatzaileak oso gertukoak dira (eta biak pi/4-etik oso gertukoak).
#
# <img src="untitled4.png" width="500" height="600"/>
#
# #### Egin beharrekoa
#
# Jarduera honetan pi/4 balioaren estimazio azterketa egin behar da. Lehendabizi, goiko algoritmoa programatu behar da (Graduan ikasitako edozein programa erabiliz) pi/4-en estimazio bat lortzeko. Ondoren, zuen kodeak goiko irudi guztien baliokideak lortu behar dira (azkenengo irudian, bi kurba jarri ordez, 5 jarriko direlarik).
#
# Jarduera honetan bikoteka lan egingo duzue eta bi mintegi saioetan burutuko da. Garrantzitsua da jarduera honetako lana klasean egitea, hau da, ez da onartuko klasetik kanpo egindako lana. Horrela, bigarren saioaren bukaeran lana bukatu ez dute taldeek, luzapen txiki bat eskatu ahal dute.
#
# Jarduera honetan egindako lana txostena batean idatzi behar da. Txostena eta egindako kodea eGela bidez bidaliko dira irakasleari bigarren saioaren bukaeran (edo luzapenaren azken momentuan).
#
# #### Ebaluazio irizpideak
#
# * Lortutako emaitzen ondorion azalpenaren eta egindako kodearen argitasuna eta zuzentasuna.
# * Finkatutako epeak errespetatzea
# * Lana klaseetan zehar egitea
